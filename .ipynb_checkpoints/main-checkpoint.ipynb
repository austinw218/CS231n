# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import utils
from generator import Generator
import numpy as np
import matplotlib.pyplot as plt
import stats
import autoencoder

# %% [markdown]
# # CIFAR

# %% [markdown]
# #### Create an object of class Generator
# The Generator class contains functionality to help generate adversarial images, such as
# - Generate adversarial images for a batch with the fool() method
# - Experiment with the parameters of the fool() method with the fool_calibrate() method
# - Visualize generated adversarial images from a random batch with _visualize() method, which is located inside fool_calibrate()

# %%
cifar_adv = Generator('cifar')
# Out:
# Files already downloaded and verified

# %%
cifar_adv.fool_calibrate(target=5, epsilon=5e-2, num_iters=30, verbose=True)
# Try adjusting the epsilon parameter above; it's set to a really high number to
# make the adversarial images easily distinguishable to the human eye
# Out:
# Took 4.01 seconds
# Number in batch that model successfully predicts: 34/50
# Number that terminated before max number of iterations: 34/50
# Number successfully fooled: 31/50
#
#
#
# Original Label: 4
# Model prediction: 5
# Original Label: 2
# Model prediction: 5
# Original Label: 3
# Model prediction: 5
# Original Label: 6
# Model prediction: 5
# Original Label: 3
# Model prediction: 5
# Original Label: 6
# Model prediction: 5
# Original Label: 2
# Model prediction: 5
# Original Label: 9
# Model prediction: 5
# Original Label: 8
# Model prediction: 5
# Original Label: 8
# Model prediction: 5
# Original Label: 9
# Model prediction: 5
# Original Label: 7
# Model prediction: 5
# Original Label: 3
# Model prediction: 5
# Original Label: 4
# Model prediction: 5
# Original Label: 1
# Model prediction: 5
# Original Label: 0
# Model prediction: 5
# Original Label: 1
# Model prediction: 5
# Original Label: 7
# Model prediction: 5
# Original Label: 2
# Model prediction: 5
# Original Label: 0
# Model prediction: 5
# Original Label: 8
# Model prediction: 5
# Original Label: 9
# Model prediction: 5
# Original Label: 2
# Model prediction: 5
# Original Label: 8
# Model prediction: 5
# Original Label: 6
# Model prediction: 5
# Original Label: 7
# Model prediction: 5
# Original Label: 8
# Model prediction: 5
# Original Label: 8
# Model prediction: 5
# Original Label: 3
# Model prediction: 5
# Original Label: 4
# Model prediction: 5
# Original Label: 7
# Model prediction: 5

# %% [markdown]
# # MNIST

# %%
mnist_adv = Generator('mnist')

# %%
target = np.random.randint(0,10,1).item()
print('Target = {}'.format(target))
mnist_adv.fool_calibrate(target=target, epsilon=5e-3, num_iters=50, max_L2_norm=2.0, verbose=True)
# Out:
# Target = 1
# Took 3.16 seconds
# Number in batch that model successfully predicts: 43/50
# Number that terminated before max number of iterations: 12/50
# Number successfully fooled: 5/50
# Number with small enough perturbation: 5/50
#
#
#
# Original Label: 4
# Model prediction: 4
# Original Label: 8
# Model prediction: 8
# Original Label: 0
# Model prediction: 0
# Original Label: 7
# Model prediction: 7
# Original Label: 2
# Model prediction: 1

# %% [markdown]
# # Create a dataset of adversarial images
# The make_dataset() method inside the Adversarial_utils class will create a dataset of adversarial images. The data stored will contained the following for each example:
# - The original image
# - The perturbation added to the image
# - The adversarial image
# - The original label for the image
# - The label for the class that the model gets tricked into predicting

# %% [markdown]
# #### MNIST

# %%
file_name = 'test_mnist'
mnist_adv.make_dataset(file_name, num_examples=30, num_iters=40, epsilon=5e-3, max_L2_norm=2.0)
# Out:
# Starting first batch...
# Finished batch 1. Generated 11.50/30 images. Time elapsed: 0.4 minutes
# Finished batch 2. Generated 19.40/30 images. Time elapsed: 0.9 minutes
# Finished batch 3. Generated 30.30/30 images. Time elapsed: 1.3 minutes
# Took 1.33 minutes
# Data saved to file: test_mnist.npz

# %% [markdown]
# #### CIFAR

# %%
file_name = 'cifar_eps_5e-3'
cifar_adv.make_dataset(file_name, num_examples=1000, num_iters=40, epsilon=5e-3, max_L2_norm=None)

# %% [markdown]
# # Load a dataset of adversarial images
# The get_adv_data() function inside utils.py will load a Pytorch dataloader object containing data for an existing dataset of adversarial images.

# %% [markdown]
# ### MNIST

# %%
adv_data = utils.get_adv_data('mnist_eps_5e-3_norm_2_num_iters_50', original_label=7, target_label=3)

# %% [markdown]
# #### Plot a few examples

# %%
sample_batch = iter(adv_data).next()

originals = sample_batch[0]
adversaries = sample_batch[2]

for i in range(20):
    plt.subplot(1,2,1)
    plt.imshow(originals[i][0].numpy())
    plt.title('Original')
    plt.xticks([])
    plt.yticks([])

    plt.subplot(1,2,2)
    plt.imshow(adversaries[i][0].numpy())
    plt.title('Adversary')
    plt.xticks([])
    plt.yticks([])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fa44ec309022> in <module>()
# ----> 1 sample_batch = iter(adv_data).next()
#       2 print(sample_batch)
#       3
#       4 originals = sample_batch[0]
#       5 adversaries = sample_batch[2]
#
# NameError: name 'adv_data' is not defined

# %% [markdown]
# ### CIFAR

# %%
adv_data = utils.get_adv_data('cifar_eps_5e-3', original_label=1, target_label=9)

# %% [markdown]
# #### Plot a few examples

# %%
sample_batch = iter(adv_data).next()

originals = sample_batch[0]
adversaries = sample_batch[2]

for i in range(20):
    plt.subplot(1,2,1)
    plt.imshow(originals[i].numpy().transpose((1,2,0)))
    plt.title('Original')
    plt.xticks([])
    plt.yticks([])

    plt.subplot(1,2,2)
    plt.imshow(adversaries[i].numpy().transpose((1,2,0)))
    plt.title('Adversary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
mnist_stats = stats.Stats("mnist_eps_5e-3_norm_2_num_iters_50")

# %%
mnist_stats.image_grid("img","average")
# Out:
# /anaconda/envs/cs231n/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /anaconda/envs/cs231n/lib/python3.6/site-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /anaconda/envs/cs231n/lib/python3.6/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /anaconda/envs/cs231n/lib/python3.6/site-packages/matplotlib/image.py:406: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /anaconda/envs/cs231n/lib/python3.6/site-packages/matplotlib/image.py:412: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /anaconda/envs/cs231n/lib/python3.6/site-packages/matplotlib/image.py:417: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# /anaconda/envs/cs231n/lib/python3.6/site-packages/matplotlib/colors.py:916: UserWarning: Warning: converting a masked element to nan.
#   dtype = np.min_scalar_type(value)
# /anaconda/envs/cs231n/lib/python3.6/site-packages/numpy/ma/core.py:716: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)

# %%
cifar_stats = stats.Stats("cifar_eps_5e-3")
cifar_stats.image_grid("img","random")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-69aab6b451bf> in <module>()
#       1 cifar_stats = stats.Stats("cifar_eps_5e-3")
# ----> 2 cifar_stats.image_grid("img","random")
#
# ~/Desktop/STANFORD/qIII/CS231n/project/stats.py in image_grid(self, content, style)
#     104         for i in range(10):
#     105             for j in range(10):
# --> 106                 self.image(i, j, content, style, False, ax[i, j])
#     107                 if i == 9:
#     108                     ax[i, j].set_xlabel("{0:d}".format(j + 1))
#
# ~/Desktop/STANFORD/qIII/CS231n/project/stats.py in image(self, orig_label, adv_label, content, style, show, ax)
#      82         if style == "random":
#      83             n = data.shape[0]
# ---> 84             image = data[random.randint(0,n),:,:,:].squeeze()
#      85         elif style == "average":
#      86             image = np.mean(data, axis=0).squeeze()
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# Autoencoder test

# Hyperparameters
num_epochs = 5
batch_size = 128
lr = 0.002
optimizer_cls = optim.Adam

# Data loader
loader_adv = utils.get_adv_data('mnist_eps_5e-3_norm_2_num_iters_50',
                                 batch_size = batch_size)


# Instantiate model
autoencoder = AutoEncoder('mnist')
loss_fn = nn.BCELoss()
optimizer = optimizer_cls(autoencoder.parameters(), lr=lr)

# Training loop
for epoch in range(num_epochs):
    print("Epoch %d" % epoch)
    
    for i, (orig, _, adv, _, _) in enumerate(loader_adv):
        out, code = autoencoder(Variable(adv))
        
        optimizer.zero_grad()
        loss = loss_fn(out, adv)
        loss.backward()
        optimizer.step()
        
    print("Loss = %.3f" % loss.data[0])
