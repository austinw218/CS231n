# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import utils
from generator import Generator
import numpy as np
import matplotlib.pyplot as plt
import stats
import autoencoder

from   torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from   torchvision import datasets, transforms
import stats

# %%
mnist_stats = stats.Stats('mnist_eps_5e-3_norm_2_num_iters_50')
cifar_stats_easy = stats.Stats('cifar_eps_5e-3')
cifar_stats_hard = stats.Stats('cifar_momentum')

# %%
mnist_stats.histogram(style='l1')

# %%
cifar_stats_easy.histogram(style='l1')

# %%
cifar_stats_hard.histogram(style='l1')

# %%
mnist_stats.histogram(style='l2')

# %%
cifar_stats_easy.histogram(style='l2')

# %%
cifar_stats_hard.histogram(style='l2')

# %%
mnist_stats.summary(style="l2")
# Out:
# mean: 1.3496662378311157
# std: 0.36185336112976074
# min: 0.014039869420230389
# max: 1.999983787536621

# %%
cifar_stats_easy.summary(style="l2")
# Out:
# mean: 0.41789838671684265
# std: 0.20149727165699005
# min: 0.02682734839618206
# max: 1.4062237739562988

# %%
cifar_stats_hard.summary(style="l2")
# Out:
# mean: 0.6513931155204773
# std: 0.22495673596858978
# min: 0.129595547914505
# max: 1.942416787147522

# %%
cifar_stats_easy.histogram(1, None, content = "org")

# %%
cifar_stats_easy.histogram(1, 2, content = "img")

# %%
mnist_stats.image('mnist',0,9,title_str = 'Average MNIST Perturbation from Label 0 to Label 9')

# %%
cifar_stats_hard.image('cifar',None, None, style = "average", title_str="Average CIFAR-10 Perturbation (Absolute Value)")

# %%
cifar_stats_hard.image_grid('mnist', title_str = "Average MNIST Perturbations")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda/envs/cs231n/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda/envs/cs231n/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...
